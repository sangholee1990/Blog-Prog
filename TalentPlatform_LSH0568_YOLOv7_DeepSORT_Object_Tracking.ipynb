# %% [markdown]
# # 환경 변수 설정

# %%
import os
from google.colab import drive

# 구글 드라이브 연결
drive.mount('/content/drive')

# 주요 설정
serviceName = 'LSH0568'
contextPath = f"/content/drive/MyDrive/COLAB/testSys-{serviceName}"

globalVar = {
    'ctxPath':  f"{contextPath}"
    , 'inpPath': f"{contextPath}/INPUT"
    , 'outPath': f"{contextPath}/OUTPUT"
    , 'figPath': f"{contextPath}/FIG"
}

for key, val in globalVar.items():
    if key.__contains__('Path'):
        os.makedirs(val, exist_ok=True)
        print(f"[CHECK] {key} : {val}")

# 작업 경로 설정
os.makedirs(f"{globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking", exist_ok=True)
os.chdir(f"{globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking")
print(f"[CHECK] getcwd : {os.getcwd()}")

# 옵션 설정
sysOpt = {

}

# 구글 드라이브 삭제
# ! rm -rf '/content/drive/MyDrive/COLAB/testSys-LSH0568'

# 구글 코랩 세션 무한 연결
# function PreventDisconnection(){
#     document.querySelector("colab-toolbar-button#connect").click()
#     console.log("클릭이 완료되었습니다.");
# }
# setInterval(PreventDisconnection, 60 * 10000)
# Out:
# Mounted at /content/drive
# [CHECK] ctxPath : /content/drive/MyDrive/COLAB/testSys-LSH0568
# [CHECK] inpPath : /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT
# [CHECK] outPath : /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT
# [CHECK] figPath : /content/drive/MyDrive/COLAB/testSys-LSH0568/FIG
# [CHECK] getcwd : /content/drive/MyDrive/COLAB/testSys-LSH0568/YOLOv7-DeepSORT-Object-Tracking

# %% [markdown]
# # 시스템 환경 구축

# %%
# # 소스코드 다운로드
# os.chdir(f"{globalVar['ctxPath']}")
# print(f"[CHECK] getcwd : {os.getcwd()}")
# ! git clone https://github.com/MuhammadMoinFaisal/YOLOv7-DeepSORT-Object-Tracking.git

# # 라이브러리 다운로드/설치
# os.chdir(f"{globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking")
# print(f"[CHECK] getcwd : {os.getcwd()}")
# ! pip install -r requirements.txt
# ! pip install easydict

# # deep_sort_pytorch 다운로드/설치
# ! gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# ! unzip 'deep_sort_pytorch.zip'

# # YOLO 학습모형 다운로드/설치
# cmd = f"wget -P {globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt"
# print(f"[CHECK] cmd : {cmd}")
# ! {cmd}

# # 샘플 파일 다운로드
# ! gdown https://drive.google.com/uc?id=1_kt1alzcLRVxet-Drx0mt_KFSd3vrtHU

# # 비즈니스 로직 다운로드
# ! gdown https://drive.google.com/uc?id=1O577NwrOWhQ8T7Ihtn-X_eD_dO-RcChk

# # 샘플 파일 다운로드
# os.chdir(f"{globalVar['inpPath']}")
# print(f"[CHECK] getcwd : {os.getcwd()}")
# ! gdown https://drive.google.com/uc?id=1O7476xFKfxcjRJK3QJpy-nljtrrW4xAr
# ! gdown https://drive.google.com/uc?id=1O811iqDcPgYC0-cjRzs62dwLscuaSTqG
# ! gdown https://drive.google.com/uc?id=1O7xeTPGBV5ySolOVKsM_iNJIdKqxZJOQ
# Out:
# [CHECK] getcwd : /content/drive/MyDrive/COLAB/testSys-LSH0568/YOLOv7-DeepSORT-Object-Tracking
# Downloading...
# From (original): https://drive.google.com/uc?id=1O577NwrOWhQ8T7Ihtn-X_eD_dO-RcChk
# From (redirected): https://drive.google.com/uc?id=1O577NwrOWhQ8T7Ihtn-X_eD_dO-RcChk&confirm=t&uuid=848cb2e6-434b-46d2-a860-0c6a632be01f
# To: /content/drive/MyDrive/COLAB/testSys-LSH0568/YOLOv7-DeepSORT-Object-Tracking/TalentPlatform-LSH0568-deep_sort_tracking_id.py
# 100% 17.4k/17.4k [00:00<00:00, 40.0MB/s]

# %% [markdown]
# # 비즈니스 로직

# %%
# 작업경로 설정
# os.chdir(f"{globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking")
# os.getcwd()

# 샘플 파일 처리
# cmd = f"python deep_sort_tracking_id.py --weights yolov7.pt  --img 640  --source test1.mp4"
# print(f"[CHECK] cmd : {cmd}")
# ! {cmd}

# %%
# 작업경로 설정
os.chdir(f"{globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking")
os.getcwd()

# 테스트 파일 처리
srcInfo = f"{globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking/TalentPlatform-LSH0568-deep_sort_tracking_id.py"
modelInfo = f"yolov7.pt"
inpInfo = f"{globalVar['inpPath']}/case_eGtahtswt_E.mp4"
# inpInfo = f"{globalVar['inpPath']}/case2_GVz6RZZmTlg.mp4"
# inpInfo = f"{globalVar['inpPath']}/case3_KHYEROW8RYA.mp4"
outInfo = f"{globalVar['outPath']}/result_20240710"

# 단위 테스트
# # cmd = f"python {srcInfo} --weights {modelInfo} --source {inpInfo} --classes 0 --save-txt --save-conf --exist-ok --save_dir {os.path.basename(outInfo)}"
# print(f"[CHECK] cmd : {cmd}")
# ! {cmd}

# 통합 테스트
keyList = ["case_eGtahtswt_E.mp4", "case2_GVz6RZZmTlg.mp4", "case3_KHYEROW8RYA.mp4"]
for key in keyList:
    inpInfo = f"{globalVar['inpPath']}/{key}"
    cmd = f"python {srcInfo} --weights {modelInfo} --source {inpInfo} --classes 0 --save-txt --save-conf --exist-ok --save_dir {os.path.basename(outInfo)}"
    print(f"[CHECK] cmd : {cmd}")
    ! {cmd}
# Out:
# [CHECK] cmd : python /content/drive/MyDrive/COLAB/testSys-LSH0568/YOLOv7-DeepSORT-Object-Tracking/TalentPlatform-LSH0568-deep_sort_tracking_id.py --weights yolov7.pt --source /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case_eGtahtswt_E.mp4 --classes 0 --save-txt --save-conf --exist-ok --save_dir result_20240710
# Namespace(weights=['yolov7.pt'], source='/content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case_eGtahtswt_E.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=True, save_conf=True, nosave=False, classes=[0], agnostic_nms=False, augment=False, update=False, save_dir='result_20240710', names='data/coco.names', exist_ok=True, no_trace=False, trailslen=64)
# YOLOR 🚀 2259cbe torch 2.3.0+cu121 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients, 104.5 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# video 1/1 (1/5036) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case_eGtahtswt_E.mp4: Done. (1367.4ms) Inference, (21.8ms) NMS
# video 1/1 (2/5036) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case_eGtahtswt_E.mp4: Done. (1220.5ms) Inference, (0.9ms) NMS
# video 1/1 (3/5036) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case_eGtahtswt_E.mp4: Done. (1222.8ms) Inference, (1.0ms) NMS

# %% [markdown]
# # 테스트 영상 보기

# %%
import glob
from IPython.display import HTML
from base64 import b64encode
import os

inpFile = f"{globalVar['outPath']}/result_20240710/*.mp4"
fileList = sorted(glob.glob(inpFile, recursive=True))
fileList

if fileList is None or len(fileList) < 1:
    print(f'inpFile : {inpFile} / 입력 자료를 확인해주세요')

for fileInfo in fileList:
    fileName = os.path.basename(fileInfo)
    # fileNameNoExt = os.path.basename(fileInfo).split('.')[0]

    saveFileInfo = fileInfo
    os.makedirs(os.path.dirname(saveFileInfo), exist_ok=True)
    print(f"[CHECK] saveFileInfo : {saveFileInfo}")

    comFileInfo = f"{globalVar['outPath']}/com_20240710/{fileName}"
    os.makedirs(os.path.dirname(comFileInfo), exist_ok=True)
    print(f"[CHECK] comFileInfo : {comFileInfo}")

    cmd = f"ffmpeg -y -i {saveFileInfo} -vcodec libx264 {comFileInfo}"
    print(f"[CHECK] cmd : {cmd}")
    ! {cmd}

    # Show video
    mp4 = open(comFileInfo,'rb').read()
    urlVid = "data:video/mp4;base64," + b64encode(mp4).decode()
    HTML("""
    <video width=1000 controls autoplay>
        <source src="%s" type="video/mp4">
    </video>
    """ % urlVid)
# Out:
# [CHECK] saveFileInfo : /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/case2_GVz6RZZmTlg.mp4
# [CHECK] comFileInfo : /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/case2_GVz6RZZmTlg.mp4
# [CHECK] cmd : ffmpeg -y -i /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/case2_GVz6RZZmTlg.mp4 -vcodec libx264 /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/case2_GVz6RZZmTlg.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/case2_GVz6RZZmTlg.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:29.23, start: 0.000000, bitrate: 2778 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 2777 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn, 2997 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x57bdbd4b9ec0] using SAR=1/1
# [libx264 @ 0x57bdbd4b9ec0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x57bdbd4b9ec0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x57bdbd4b9ec0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/case2_GVz6RZZmTlg.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  876 fps= 13 q=-1.0 Lsize=    4449kB time=00:00:29.12 bitrate=1251.2kbits/s speed=0.445x
# video:4439kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.227450%
# [libx264 @ 0x57bdbd4b9ec0] frame I:5     Avg QP:17.69  size: 46799
# [libx264 @ 0x57bdbd4b9ec0] frame P:452   Avg QP:21.83  size:  8547
# [libx264 @ 0x57bdbd4b9ec0] frame B:419   Avg QP:25.54  size:  1068
# [libx264 @ 0x57bdbd4b9ec0] consecutive B-frames: 22.7% 37.9%  7.9% 31.5%
# [libx264 @ 0x57bdbd4b9ec0] mb I  I16..4: 19.7% 71.0%  9.4%
# [libx264 @ 0x57bdbd4b9ec0] mb P  I16..4:  0.2%  3.2%  0.1%  P16..4: 46.0%  9.4%  4.6%  0.0%  0.0%    skip:36.5%
# [libx264 @ 0x57bdbd4b9ec0] mb B  I16..4:  0.0%  0.2%  0.0%  B16..8: 27.3%  0.2%  0.0%  direct: 0.0%  skip:72.2%  L0:42.4% L1:56.5% BI: 1.1%
# [libx264 @ 0x57bdbd4b9ec0] 8x8 transform intra:86.8% inter:83.0%
# [libx264 @ 0x57bdbd4b9ec0] coded y,uvDC,uvAC intra: 80.2% 3.0% 1.1% inter: 10.4% 0.5% 0.1%
# [libx264 @ 0x57bdbd4b9ec0] i16 v,h,dc,p: 53% 16% 13% 18%
# [libx264 @ 0x57bdbd4b9ec0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 28% 27%  4%  4%  4%  6%  4%  6%
# [libx264 @ 0x57bdbd4b9ec0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 31%  7%  5%  7%  6%  7%  5%  6%
# [libx264 @ 0x57bdbd4b9ec0] i8c dc,h,v,p: 96%  2%  2%  0%
# [libx264 @ 0x57bdbd4b9ec0] Weighted P-Frames: Y:0.2% UV:0.0%
# [libx264 @ 0x57bdbd4b9ec0] ref P L0: 70.7% 15.4% 10.9%  3.1%  0.0%
# [libx264 @ 0x57bdbd4b9ec0] ref B L0: 85.3% 13.1%  1.6%
# [libx264 @ 0x57bdbd4b9ec0] ref B L1: 96.9%  3.1%
# [libx264 @ 0x57bdbd4b9ec0] kb/s:1243.94
# [CHECK] saveFileInfo : /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/case3_KHYEROW8RYA.mp4
# [CHECK] comFileInfo : /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/case3_KHYEROW8RYA.mp4
# [CHECK] cmd : ffmpeg -y -i /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/case3_KHYEROW8RYA.mp4 -vcodec libx264 /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/case3_KHYEROW8RYA.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/case3_KHYEROW8RYA.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:01:30.36, start: 0.000000, bitrate: 9210 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], 9209 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn, 2997 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5d4bf7e77c80] using SAR=1/1
# [libx264 @ 0x5d4bf7e77c80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5d4bf7e77c80] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5d4bf7e77c80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/case3_KHYEROW8RYA.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 2708 fps=7.4 q=-1.0 Lsize=   43729kB time=00:01:30.25 bitrate=3969.0kbits/s speed=0.246x
# video:43699kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.068340%
# [libx264 @ 0x5d4bf7e77c80] frame I:22    Avg QP:18.55  size:130946
# [libx264 @ 0x5d4bf7e77c80] frame P:1175  Avg QP:22.02  size: 24134
# [libx264 @ 0x5d4bf7e77c80] frame B:1511  Avg QP:25.56  size:  8941
# [libx264 @ 0x5d4bf7e77c80] consecutive B-frames: 20.7% 11.7%  8.8% 58.8%
# [libx264 @ 0x5d4bf7e77c80] mb I  I16..4: 15.6% 78.8%  5.6%
# [libx264 @ 0x5d4bf7e77c80] mb P  I16..4:  2.7% 10.9%  0.2%  P16..4: 38.2%  7.8%  3.6%  0.0%  0.0%    skip:36.6%
# [libx264 @ 0x5d4bf7e77c80] mb B  I16..4:  0.8%  3.3%  0.0%  B16..8: 30.9%  2.8%  0.4%  direct: 1.0%  skip:60.8%  L0:53.8% L1:42.9% BI: 3.4%
# [libx264 @ 0x5d4bf7e77c80] 8x8 transform intra:79.2% inter:86.8%
# [libx264 @ 0x5d4bf7e77c80] coded y,uvDC,uvAC intra: 52.3% 62.9% 3.9% inter: 10.5% 10.5% 0.2%
# [libx264 @ 0x5d4bf7e77c80] i16 v,h,dc,p: 26% 32% 24% 18%
# [libx264 @ 0x5d4bf7e77c80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 25% 35%  3%  2%  3%  3%  2%  3%
# [libx264 @ 0x5d4bf7e77c80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 31% 12%  3%  4%  4%  4%  3%  3%
# [libx264 @ 0x5d4bf7e77c80] i8c dc,h,v,p: 46% 29% 21%  4%
# [libx264 @ 0x5d4bf7e77c80] Weighted P-Frames: Y:0.5% UV:0.4%
# [libx264 @ 0x5d4bf7e77c80] ref P L0: 68.2%  9.9% 15.8%  6.2%  0.0%
# [libx264 @ 0x5d4bf7e77c80] ref B L0: 83.7% 13.4%  2.9%
# [libx264 @ 0x5d4bf7e77c80] ref B L1: 94.1%  5.9%
# [libx264 @ 0x5d4bf7e77c80] kb/s:3961.82
# [CHECK] saveFileInfo : /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/case_eGtahtswt_E.mp4
# [CHECK] comFileInfo : /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/case_eGtahtswt_E.mp4
# [CHECK] cmd : ffmpeg -y -i /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/case_eGtahtswt_E.mp4 -vcodec libx264 /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/case_eGtahtswt_E.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/case_eGtahtswt_E.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:02:48.04, start: 0.000000, bitrate: 5050 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], 5049 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn, 2997 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5691fe088480] using SAR=1/1
# [libx264 @ 0x5691fe088480] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5691fe088480] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5691fe088480] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/case_eGtahtswt_E.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 5036 fps=9.1 q=-1.0 Lsize=   51431kB time=00:02:47.93 bitrate=2508.9kbits/s speed=0.304x
# video:51380kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.099871%
# [libx264 @ 0x5691fe088480] frame I:28    Avg QP:16.82  size: 68656
# [libx264 @ 0x5691fe088480] frame P:2458  Avg QP:20.95  size: 17319
# [libx264 @ 0x5691fe088480] frame B:2550  Avg QP:22.99  size:  3184
# [libx264 @ 0x5691fe088480] consecutive B-frames: 27.4% 13.4%  6.0% 53.3%
# [libx264 @ 0x5691fe088480] mb I  I16..4: 22.9% 71.2%  6.0%
# [libx264 @ 0x5691fe088480] mb P  I16..4:  4.7% 13.7%  0.2%  P16..4: 36.6%  4.2%  1.9%  0.0%  0.0%    skip:38.7%
# [libx264 @ 0x5691fe088480] mb B  I16..4:  0.6%  1.3%  0.0%  B16..8: 24.1%  0.6%  0.0%  direct: 0.6%  skip:72.7%  L0:54.6% L1:44.6% BI: 0.8%
# [libx264 @ 0x5691fe088480] 8x8 transform intra:73.2% inter:89.5%
# [libx264 @ 0x5691fe088480] coded y,uvDC,uvAC intra: 32.9% 37.1% 1.9% inter: 5.0% 6.7% 0.1%
# [libx264 @ 0x5691fe088480] i16 v,h,dc,p: 28% 44% 17% 11%
# [libx264 @ 0x5691fe088480] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 31% 35%  2%  1%  1%  2%  1%  2%
# [libx264 @ 0x5691fe088480] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 34% 12%  3%  4%  3%  4%  2%  2%
# [libx264 @ 0x5691fe088480] i8c dc,h,v,p: 55% 27% 17%  2%
# [libx264 @ 0x5691fe088480] Weighted P-Frames: Y:0.7% UV:0.4%
# [libx264 @ 0x5691fe088480] ref P L0: 78.5%  7.4% 10.7%  3.4%  0.0%
# [libx264 @ 0x5691fe088480] ref B L0: 79.5% 17.4%  3.1%
# [libx264 @ 0x5691fe088480] ref B L1: 94.3%  5.7%
# [libx264 @ 0x5691fe088480] kb/s:2504.83
# [CHECK] saveFileInfo : /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/test1.mp4
# [CHECK] comFileInfo : /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/test1.mp4
# [CHECK] cmd : ffmpeg -y -i /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/test1.mp4 -vcodec libx264 /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/test1.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/result_20240710/test1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:31.40, start: 0.000000, bitrate: 3034 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 3033 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56d930763c00] using SAR=1/1
# [libx264 @ 0x56d930763c00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56d930763c00] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x56d930763c00] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT/com_20240710/test1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  942 fps= 25 q=-1.0 Lsize=    4544kB time=00:00:31.30 bitrate=1189.4kbits/s speed=0.844x
# video:4536kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.197078%
# [libx264 @ 0x56d930763c00] frame I:4     Avg QP:17.42  size: 62038
# [libx264 @ 0x56d930763c00] frame P:721   Avg QP:20.46  size:  5830
# [libx264 @ 0x56d930763c00] frame B:217   Avg QP:21.41  size:   884
# [libx264 @ 0x56d930763c00] consecutive B-frames: 56.3% 37.6%  4.5%  1.7%
# [libx264 @ 0x56d930763c00] mb I  I16..4: 22.0% 69.6%  8.3%
# [libx264 @ 0x56d930763c00] mb P  I16..4:  0.9%  3.4%  0.1%  P16..4: 18.6%  4.7%  3.1%  0.0%  0.0%    skip:69.3%
# [libx264 @ 0x56d930763c00] mb B  I16..4:  0.2%  0.4%  0.0%  B16..8: 16.9%  0.6%  0.0%  direct: 0.2%  skip:81.6%  L0:46.0% L1:51.7% BI: 2.3%
# [libx264 @ 0x56d930763c00] 8x8 transform intra:76.3% inter:68.0%
# [libx264 @ 0x56d930763c00] coded y,uvDC,uvAC intra: 39.3% 57.3% 8.8% inter: 5.8% 5.9% 0.2%
# [libx264 @ 0x56d930763c00] i16 v,h,dc,p: 26% 36% 31%  6%
# [libx264 @ 0x56d930763c00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 25% 48%  2%  1%  1%  2%  1%  2%
# [libx264 @ 0x56d930763c00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 30% 17%  5%  6%  4%  6%  5%  4%
# [libx264 @ 0x56d930763c00] i8c dc,h,v,p: 43% 34% 19%  4%
# [libx264 @ 0x56d930763c00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56d930763c00] ref P L0: 80.4%  9.2%  8.0%  2.5%
# [libx264 @ 0x56d930763c00] ref B L0: 82.1% 17.4%  0.5%
# [libx264 @ 0x56d930763c00] ref B L1: 99.8%  0.2%
# [libx264 @ 0x56d930763c00] kb/s:1183.10
